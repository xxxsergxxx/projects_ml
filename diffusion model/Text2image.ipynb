# %% [markdown]
# HW
#
# Generate 10 non standard images

# %% [markdown]
# Get model from
#
# [Huggingface](https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0)

# %%
pip install -U diffusers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 27.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.30.3
#     Uninstalling diffusers-0.30.3:
#       Successfully uninstalled diffusers-0.30.3
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt

from diffusers import DiffusionPipeline
import torch
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]

# %%
pipe = DiffusionPipeline.from_pretrained("stabilityai/stable-diffusion-xl-base-1.0", torch_dtype=torch.float16, use_safetensors=True, variant="fp16")
pipe.to("cuda")

# if using torch < 2.0
# pipe.enable_xformers_memory_efficient_attention()

prompt = "An astronaut riding a green horse"

images = pipe(prompt=prompt).images[0]
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# Fetching 19 files:   0%|          | 0/19 [00:00<?, ?it/s]
# model.fp16.safetensors:   0%|          | 0.00/1.39G [00:00<?, ?B/s]
# tokenizer/tokenizer_config.json:   0%|          | 0.00/737 [00:00<?, ?B/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# text_encoder_2/config.json:   0%|          | 0.00/575 [00:00<?, ?B/s]
# ...

# %% [markdown]
# #Image 1 - astraunaut riding a green horse

# %%
# output image
plt.imshow(images)
plt.axis("off")
plt.show()

# %% [markdown]
# #Image 2 pink alien eating a pumpkine

# %%
prompt1 = "pink alien eating a pumpkine"

images1 = pipe(prompt=prompt1).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# output image
plt.imshow(images1)
plt.axis("off")
plt.show()

# %% [markdown]
# #Image 3 the yellow birch forest is covered with the remains of a blue apple

# %%
prompt2 = "the yellow birch forest is covered with the remains of a blue apple"

images2 = pipe(prompt=prompt2).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# output image
plt.imshow(images2)
plt.axis("off")
plt.show()

# %% [markdown]
# #Image 4 a purple deer with dog ears stands on a hut and howls at the moon

# %%
prompt3 = "a purple deer with dog ears stands on a hut and howls at the moon"

images3 = pipe(prompt=prompt3).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# output image
plt.imshow(images3)
plt.axis("off")
plt.show()

# %% [markdown]
# #image 5 a snowman is covered in oil, has a pan on his head and eats snickers and holds wine

# %%
prompt4 = "a snowman is covered in oil, has a pan on his head and eats snickers and holds wine"

images4 = pipe(prompt=prompt4).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# output image
plt.imshow(images4)
plt.axis("off")
plt.show()

# %% [markdown]
# #image 6 A cat wearing skates in a Christmas costume plays the piano and dogs in reindeer costumes behind him.

# %%
prompt5 = "A cat wearing skates in a Christmas costume plays the piano and dogs in reindeer costumes behind him."

images5 = pipe(prompt=prompt5).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# output image
plt.imshow(images5)
plt.axis("off")
plt.show()

# %% [markdown]
# #image 7 Fanta is flowing from the coffee machine and behind it are purple mushrooms. between the mushrooms are coca cola bottles with a vacuum cleaner inside

# %%
prompt6 = "Fanta is flowing from the coffee machine and behind it are purple mushrooms. between the mushrooms are coca cola bottles with a vacuum cleaner inside"

images6 = pipe(prompt=prompt6).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# output image
plt.imshow(images6)
plt.axis("off")
plt.show()

# %% [markdown]
# #image 8  A red Labrador flies in cosmo space near Saturn on a Tesla car

# %%
prompt7 = "A red Labrador flies in cosmo space near Saturn on a Tesla car"

images7 = pipe(prompt=prompt7).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# output image
plt.imshow(images7)
plt.axis("off")
plt.show()

# %% [markdown]
# #image 9 Many people in animal costumes came to the Eiffel Tower. in the background, chocolate fountains made of red chocolate

# %%
prompt8 = "Many people in animal costumes came to the Eiffel Tower. in the background, chocolate fountains made of red chocolate"

images8 = pipe(prompt=prompt8).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# output image
plt.imshow(images8)
plt.axis("off")
plt.show()

# %% [markdown]
# #image 10 mad corn on roller skates with a shovel in hand running after a man with a squirrel tail sticking out of his ass and squirrel ears on his head

# %%
prompt9 = " mad corn on roller skates with a shovel in hand running after a man"

images9 = pipe(prompt=prompt9).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# output image
plt.imshow(images9)
plt.axis("off")
plt.show()
